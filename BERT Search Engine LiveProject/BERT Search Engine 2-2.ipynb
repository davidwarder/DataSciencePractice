# %%
#!pip install faiss-cpu
#!pip install transformers
#!pip install sentence-transformers

import json
import torch
import numpy as np
import faiss
import sentence_transformers
from sentence_transformers import SentenceTransformer
import pandas as pd

# %%
with open('/content/data.json') as f:
  data = pd.DataFrame(json.load(f))
model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')
data
# Out:
#                                      title  \
# 0                                 Pandemic
# 1                 Epidemiology of HIV/AIDS
# 2                          Antonine Plague
# 3                Basic reproduction number
# 4                       Bills of mortality
# 5                                  Cholera
# 6                        COVID-19 pandemic
# 7                        Crimson Contagion
# 8                                Disease X
# 9                                Event 201
# 10                                HIV/AIDS
# 11                      HIV/AIDS in Yunnan
# 12                     Pandemic prevention
# 13  Pandemic Severity Assessment Framework
# 14                 Pandemic severity index
# 15                       Plague of Cyprian
# 16                         PREDICT (USAID)
# 17          1929–1930 psittacosis pandemic
# 18         Science diplomacy and pandemics
# 19                             Spanish flu
# 20                           Superspreader
# 21                         Swine influenza
# 22        Targeted immunization strategies
# 23    Unified Victim Identification System
# 24                              Viral load
# 25                                   Virus
#
#                                                  text  \
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
# 1   HIV/AIDS, or Human Immunodeficiency Virus, is ...
# 2   The Antonine Plague of 165 to 180 AD, also kno...
# 3   In epidemiology, the basic reproduction number...
# 4   Bills of mortality were the weekly mortality s...
# 5   Cholera is an infection of the small intestine...
# 6   The COVID-19 pandemic, also known as the coron...
# 7   Crimson Contagion was a joint exercise conduct...
# 8   Disease X is a placeholder name that was adopt...
# 9   The Johns Hopkins Center for Health Security (...
# 10  Human immunodeficiency virus infection and acq...
# 11  The People's Republic of China's first reporte...
# 12  Pandemic prevention is the organization and ma...
# 13  The Pandemic Severity Assessment Framework (PS...
# 14  The pandemic severity index (PSI) was a propos...
# 15  The Plague of Cyprian was a pandemic that affl...
# 16  PREDICT was an epidemiological research progra...
# 17  The 1929–1930 psittacosis pandemic, also known...
# 18  Science diplomacy is the collaborative efforts...
# 19  The Spanish flu, also known as the 1918 flu pa...
# 20  A superspreader is an unusually contagious org...
# 21  Swine influenza is an infection caused by any ...
# 22  Targeted immunization strategies are approache...
# 23  The Unified Victim Identification System (UVIS...
# 24  Viral load, also known as viral burden, viral ...
# 25  A virus is a submicroscopic infectious agent t...
#
#                                                   url
# 0              https://en.wikipedia.org/wiki/Pandemic
# 1   https://en.wikipedia.org/wiki/Epidemiology_of_...
# 2       https://en.wikipedia.org/wiki/Antonine_Plague
# 3   https://en.wikipedia.org/wiki/Basic_reproducti...
# 4    https://en.wikipedia.org/wiki/Bills_of_mortality
# 5               https://en.wikipedia.org/wiki/Cholera
# 6     https://en.wikipedia.org/wiki/COVID-19_pandemic
# 7     https://en.wikipedia.org/wiki/Crimson_Contagion
# 8             https://en.wikipedia.org/wiki/Disease_X
# 9   https://en.wikipedia.org/wiki/Johns_Hopkins_Ce...
# 10             https://en.wikipedia.org/wiki/HIV/AIDS
# 11   https://en.wikipedia.org/wiki/HIV/AIDS_in_Yunnan
# 12  https://en.wikipedia.org/wiki/Pandemic_prevention
# 13  https://en.wikipedia.org/wiki/Pandemic_Severit...
# 14  https://en.wikipedia.org/wiki/Pandemic_severit...
# 15    https://en.wikipedia.org/wiki/Plague_of_Cyprian
# 16      https://en.wikipedia.org/wiki/PREDICT_(USAID)
# 17  https://en.wikipedia.org/wiki/1929%E2%80%93193...
# 18  https://en.wikipedia.org/wiki/Science_diplomac...
# 19          https://en.wikipedia.org/wiki/Spanish_flu
# 20        https://en.wikipedia.org/wiki/Superspreader
# 21      https://en.wikipedia.org/wiki/Swine_influenza
# 22  https://en.wikipedia.org/wiki/Targeted_immuniz...
# 23  https://en.wikipedia.org/wiki/Unified_Victim_I...
# 24           https://en.wikipedia.org/wiki/Viral_load
# 25                https://en.wikipedia.org/wiki/Virus

# %%
embeddings = model.encode(data.text.to_list(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
embeddings = np.array([embedding for embedding in embeddings]).astype("float32")
index = faiss.IndexFlatL2(embeddings.shape[1])
index = faiss.IndexIDMap(index)
index.add_with_ids(embeddings, data.index.to_numpy())
print(f"Number of vectors in the Faiss index: {index.ntotal}")
# Out:
# Number of vectors in the Faiss index: 26

# %%
D, I = index.search(np.array([embeddings[12]]), k=5)
print(f'L2 distance: {D.flatten().tolist()}\n\nMAG paper IDs: {I.flatten().tolist()}')
for i in I:
  print(data.iloc[i])
# Out:
# L2 distance: [0.0, 0.7909256815910339, 1.016036868095398, 1.0702069997787476, 1.1270612478256226]
#
# MAG paper IDs: [12, 0, 22, 13, 6]
#                                      title  \
# 12                     Pandemic prevention
# 0                                 Pandemic
# 22        Targeted immunization strategies
# 13  Pandemic Severity Assessment Framework
# 6                        COVID-19 pandemic
#
#                                                  text  \
# 12  Pandemic prevention is the organization and ma...
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
# 22  Targeted immunization strategies are approache...
# 13  The Pandemic Severity Assessment Framework (PS...
# 6   The COVID-19 pandemic, also known as the coron...
#
#                                                   url
# 12  https://en.wikipedia.org/wiki/Pandemic_prevention
# 0              https://en.wikipedia.org/wiki/Pandemic
# 22  https://en.wikipedia.org/wiki/Targeted_immuniz...
# 13  https://en.wikipedia.org/wiki/Pandemic_Severit...
# 6     https://en.wikipedia.org/wiki/COVID-19_pandemic

# %%
def sentence_search(search_string):
  D, I = index.search(np.array(model.encode([search_string])).astype("float32"), k=5)
  print(f'L2 distance: {D.flatten().tolist()}\n\nMAG paper IDs: {I.flatten().tolist()}')
  for i in I:
    print(data.iloc[i])

# %%
with open('/content/questions.json') as f:
  questions = json.load(f)
questions
# Out:
# ['How many people have died during Black Death?',
#  'Which diseases can be transmitted by animals?',
#  'Connection between climate change and a likelihood of a pandemic',
#  'What is an example of a latent virus',
#  'Viruses in nanotechnology',
#  'Giant viruses classification',
#  'What are the notable pandemic prevention organizations?',
#  'How many leprosy outbreaks are known to happen?',
#  'What are the geographic areas with the highest transmission of malaria?',
#  'How to prevent the spread of viral infections?']

# %%
for question in questions:
  print(question)
  sentence_search(question)
  print('-------------------------------------------')
# Out:
# How many people have died during Black Death?
# L2 distance: [1.1505247354507446, 1.1768505573272705, 1.3450472354888916, 1.4118623733520508, 1.4184632301330566]
#
# MAG paper IDs: [0, 2, 1, 19, 4]
#                        title  \
# 0                   Pandemic
# 2            Antonine Plague
# 1   Epidemiology of HIV/AIDS
# 19               Spanish flu
# 4         Bills of mortality
#
#                                                  text  \
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
# 2   The Antonine Plague of 165 to 180 AD, also kno...
# 1   HIV/AIDS, or Human Immunodeficiency Virus, is ...
# 19  The Spanish flu, also known as the 1918 flu pa...
# 4   Bills of mortality were the weekly mortality s...
#
#                                                   url
# 0              https://en.wikipedia.org/wiki/Pandemic
# 2       https://en.wikipedia.org/wiki/Antonine_Plague
# 1   https://en.wikipedia.org/wiki/Epidemiology_of_...
# 19          https://en.wikipedia.org/wiki/Spanish_flu
# 4    https://en.wikipedia.org/wiki/Bills_of_mortality
# -------------------------------------------
# Which diseases can be transmitted by animals?
# L2 distance: [1.073493242263794, 1.0777902603149414, 1.2284510135650635, 1.2625939846038818, 1.2724583148956299]
#
# MAG paper IDs: [21, 10, 8, 25, 0]
#               title                                               text  \
# 21  Swine influenza  Swine influenza is an infection caused by any ...
# 10         HIV/AIDS  Human immunodeficiency virus infection and acq...
# 8         Disease X  Disease X is a placeholder name that was adopt...
# 25            Virus  A virus is a submicroscopic infectious agent t...
# 0          Pandemic  A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
#
#                                               url
# 21  https://en.wikipedia.org/wiki/Swine_influenza
# 10         https://en.wikipedia.org/wiki/HIV/AIDS
# 8         https://en.wikipedia.org/wiki/Disease_X
# 25            https://en.wikipedia.org/wiki/Virus
# 0          https://en.wikipedia.org/wiki/Pandemic
# -------------------------------------------
# Connection between climate change and a likelihood of a pandemic
# L2 distance: [0.9860728979110718, 1.0640275478363037, 1.0847718715667725, 1.2044613361358643, 1.2173999547958374]
#
# MAG paper IDs: [0, 6, 12, 13, 14]
#                                      title  \
# 0                                 Pandemic
# 6                        COVID-19 pandemic
# 12                     Pandemic prevention
# 13  Pandemic Severity Assessment Framework
# 14                 Pandemic severity index
#
#                                                  text  \
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
# 6   The COVID-19 pandemic, also known as the coron...
# 12  Pandemic prevention is the organization and ma...
# 13  The Pandemic Severity Assessment Framework (PS...
# 14  The pandemic severity index (PSI) was a propos...
#
#                                                   url
# 0              https://en.wikipedia.org/wiki/Pandemic
# 6     https://en.wikipedia.org/wiki/COVID-19_pandemic
# 12  https://en.wikipedia.org/wiki/Pandemic_prevention
# 13  https://en.wikipedia.org/wiki/Pandemic_Severit...
# 14  https://en.wikipedia.org/wiki/Pandemic_severit...
# -------------------------------------------
# What is an example of a latent virus
# L2 distance: [1.010846495628357, 1.2243729829788208, 1.2524139881134033, 1.2775453329086304, 1.344724178314209]
#
# MAG paper IDs: [25, 21, 24, 10, 8]
#               title                                               text  \
# 25            Virus  A virus is a submicroscopic infectious agent t...
# 21  Swine influenza  Swine influenza is an infection caused by any ...
# 24       Viral load  Viral load, also known as viral burden, viral ...
# 10         HIV/AIDS  Human immunodeficiency virus infection and acq...
# 8         Disease X  Disease X is a placeholder name that was adopt...
#
#                                               url
# 25            https://en.wikipedia.org/wiki/Virus
# 21  https://en.wikipedia.org/wiki/Swine_influenza
# 24       https://en.wikipedia.org/wiki/Viral_load
# 10         https://en.wikipedia.org/wiki/HIV/AIDS
# 8         https://en.wikipedia.org/wiki/Disease_X
# -------------------------------------------
# Viruses in nanotechnology
# L2 distance: [0.9619507789611816, 1.3402737379074097, 1.4206843376159668, 1.440219521522522, 1.4412660598754883]
#
# MAG paper IDs: [25, 24, 8, 10, 21]
#               title                                               text  \
# 25            Virus  A virus is a submicroscopic infectious agent t...
# 24       Viral load  Viral load, also known as viral burden, viral ...
# 8         Disease X  Disease X is a placeholder name that was adopt...
# 10         HIV/AIDS  Human immunodeficiency virus infection and acq...
# 21  Swine influenza  Swine influenza is an infection caused by any ...
#
#                                               url
# 25            https://en.wikipedia.org/wiki/Virus
# 24       https://en.wikipedia.org/wiki/Viral_load
# 8         https://en.wikipedia.org/wiki/Disease_X
# 10         https://en.wikipedia.org/wiki/HIV/AIDS
# 21  https://en.wikipedia.org/wiki/Swine_influenza
# -------------------------------------------
# Giant viruses classification
# L2 distance: [0.8686521649360657, 1.1960546970367432, 1.2082014083862305, 1.340796709060669, 1.4080495834350586]
#
# MAG paper IDs: [25, 8, 24, 21, 10]
#               title                                               text  \
# 25            Virus  A virus is a submicroscopic infectious agent t...
# 8         Disease X  Disease X is a placeholder name that was adopt...
# 24       Viral load  Viral load, also known as viral burden, viral ...
# 21  Swine influenza  Swine influenza is an infection caused by any ...
# 10         HIV/AIDS  Human immunodeficiency virus infection and acq...
#
#                                               url
# 25            https://en.wikipedia.org/wiki/Virus
# 8         https://en.wikipedia.org/wiki/Disease_X
# 24       https://en.wikipedia.org/wiki/Viral_load
# 21  https://en.wikipedia.org/wiki/Swine_influenza
# 10         https://en.wikipedia.org/wiki/HIV/AIDS
# -------------------------------------------
# What are the notable pandemic prevention organizations?
# L2 distance: [0.7589758634567261, 0.9743019342422485, 1.0271685123443604, 1.0634829998016357, 1.1051578521728516]
#
# MAG paper IDs: [12, 0, 6, 13, 9]
#                                      title  \
# 12                     Pandemic prevention
# 0                                 Pandemic
# 6                        COVID-19 pandemic
# 13  Pandemic Severity Assessment Framework
# 9                                Event 201
#
#                                                  text  \
# 12  Pandemic prevention is the organization and ma...
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
# 6   The COVID-19 pandemic, also known as the coron...
# 13  The Pandemic Severity Assessment Framework (PS...
# 9   The Johns Hopkins Center for Health Security (...
#
#                                                   url
# 12  https://en.wikipedia.org/wiki/Pandemic_prevention
# 0              https://en.wikipedia.org/wiki/Pandemic
# 6     https://en.wikipedia.org/wiki/COVID-19_pandemic
# 13  https://en.wikipedia.org/wiki/Pandemic_Severit...
# 9   https://en.wikipedia.org/wiki/Johns_Hopkins_Ce...
# -------------------------------------------
# How many leprosy outbreaks are known to happen?
# L2 distance: [0.9286717772483826, 0.9693323373794556, 1.089375615119934, 1.098088026046753, 1.154753565788269]
#
# MAG paper IDs: [1, 10, 6, 21, 0]
#                        title  \
# 1   Epidemiology of HIV/AIDS
# 10                  HIV/AIDS
# 6          COVID-19 pandemic
# 21           Swine influenza
# 0                   Pandemic
#
#                                                  text  \
# 1   HIV/AIDS, or Human Immunodeficiency Virus, is ...
# 10  Human immunodeficiency virus infection and acq...
# 6   The COVID-19 pandemic, also known as the coron...
# 21  Swine influenza is an infection caused by any ...
# 0   A pandemic (from Greek πᾶν, pan, "all" and δῆμ...
#
#                                                   url
# 1   https://en.wikipedia.org/wiki/Epidemiology_of_...
# 10             https://en.wikipedia.org/wiki/HIV/AIDS
# 6     https://en.wikipedia.org/wiki/COVID-19_pandemic
# 21      https://en.wikipedia.org/wiki/Swine_influenza
# 0              https://en.wikipedia.org/wiki/Pandemic
# -------------------------------------------
# What are the geographic areas with the highest transmission of malaria?
# L2 distance: [1.1201435327529907, 1.3502874374389648, 1.3630638122558594, 1.4181842803955078, 1.435357928276062]
#
# MAG paper IDs: [1, 10, 11, 2, 21]
#                        title  \
# 1   Epidemiology of HIV/AIDS
# 10                  HIV/AIDS
# 11        HIV/AIDS in Yunnan
# 2            Antonine Plague
# 21           Swine influenza
#
#                                                  text  \
# 1   HIV/AIDS, or Human Immunodeficiency Virus, is ...
# 10  Human immunodeficiency virus infection and acq...
# 11  The People's Republic of China's first reporte...
# 2   The Antonine Plague of 165 to 180 AD, also kno...
# 21  Swine influenza is an infection caused by any ...
#
#                                                   url
# 1   https://en.wikipedia.org/wiki/Epidemiology_of_...
# 10             https://en.wikipedia.org/wiki/HIV/AIDS
# 11   https://en.wikipedia.org/wiki/HIV/AIDS_in_Yunnan
# 2       https://en.wikipedia.org/wiki/Antonine_Plague
# 21      https://en.wikipedia.org/wiki/Swine_influenza
# -------------------------------------------
# How to prevent the spread of viral infections?
# L2 distance: [0.9857141375541687, 1.0092229843139648, 1.1932005882263184, 1.2763174772262573, 1.2951265573501587]
#
# MAG paper IDs: [10, 25, 24, 11, 6]
#                  title                                               text  \
# 10            HIV/AIDS  Human immunodeficiency virus infection and acq...
# 25               Virus  A virus is a submicroscopic infectious agent t...
# 24          Viral load  Viral load, also known as viral burden, viral ...
# 11  HIV/AIDS in Yunnan  The People's Republic of China's first reporte...
# 6    COVID-19 pandemic  The COVID-19 pandemic, also known as the coron...
#
#                                                  url
# 10            https://en.wikipedia.org/wiki/HIV/AIDS
# 25               https://en.wikipedia.org/wiki/Virus
# 24          https://en.wikipedia.org/wiki/Viral_load
# 11  https://en.wikipedia.org/wiki/HIV/AIDS_in_Yunnan
# 6    https://en.wikipedia.org/wiki/COVID-19_pandemic
# -------------------------------------------

# %%
faiss.write_index(index, '/content/Bert_Search_Engine_2-2.index')
